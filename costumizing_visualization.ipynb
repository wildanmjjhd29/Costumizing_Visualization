# %% [markdown]
# # Costumizing Visualization

# %%
import matplotlib.pyplot as plt

# membuat componet figure dan axis
fig, ax = plt.subplots()

data_x = [1,2,3,4,5,6,7]
data_y = [10,20,25,30,15,18,10]

# memberikan data kedalam axis
ax.plot(data_x,data_y)
plt.show()

# %% [markdown]
# ### Custom Linestyle

# %%
import matplotlib.pyplot as plt

# membuat componet figure dan axis
fig, ax = plt.subplots()

data_x = [1,2,3,4,5,6,7]
data_y = [10,20,25,30,15,18,10]

# memberikan data kedalam axis
ax.plot(data_x,data_y, marker='o', linestyle='dotted')
plt.show()

# %% [markdown]
# ### Memilih Warna

# %%
# memberikan data dalam axis
import matplotlib.pyplot as plt

# membuat componet figure dan axis
fig, ax = plt.subplots()

data_x = [1,2,3,4,5,6,7]
data_y = [10,20,25,30,15,18,10]

# memberikan data kedalam axis
ax.plot(data_x,data_y, marker='o', linestyle='dotted', color='#000')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12,8))
x = np.linspace(0,10,100)
# menggunkana nam dari warnanya
plt.plot(x, np.sin(x), color='green')
# menggunakan format rgbcmyk
plt.plot(x, np.sin(x-1), color='m')
# menggunakan format grayscale(0 1)
plt.plot(x, np.sin(x-2), color='0.5')
# menggunakan format RRGGBB, value from 00 to FF
plt.plot(x, np.sin(x-3), color='#FF0037')
# format (R, G, B) 0-1
plt.plot(x, np.sin(x-4), color=(0,1,0.5))
# HTML color names support
plt.plot(x, np.sin(x-5), color='DarkGreen')
plt.show()

# %% [markdown]
# ### Custom Axis Label And Title

# %%
# memberikan data dalam axis
import matplotlib.pyplot as plt

# membuat componet figure dan axis
fig, ax = plt.subplots()

data_x = [1,2,3,4,5,6,7]
data_y = [10,20,25,30,15,18,10]

# memberikan data kedalam axis
ax.plot(data_x,data_y, marker='o', linestyle='dotted', color='aqua')

# mengubah axis label dan title
ax.set_xlabel('X Label Axis')
ax.set_ylabel('Y Label Axis')
ax.set_title('Title of Graph')

plt.show()

# %% [markdown]
# ### Axis Limit

# %%
plt.figure(figsize=(8,6))
plt.plot(x, x+1, linestyle='solid')
plt.plot(x, x+2, linestyle='dashed')
plt.show()

# %%
#menggunakan method .xlim dan .ylim
plt.figure(figsize=(8,6))
plt.plot(x, x+1, linestyle='solid')
plt.plot(x, x+2, linestyle='dashed')
plt.xlim(2,8)
plt.ylim(2,10)
plt.show()

# %%
#menggunakan .axis
plt.figure(figsize=(8,6))
plt.plot(x, x+1, linestyle='solid')
plt.plot(x, x+2, linestyle='dashed')
plt.axis([2,8,2,10]) # [xmin, xmax, ymin, ymax]
plt.show()

# %% [markdown]
# ### Legend

# %%
plt.figure(figsize=(7,6))
plt.plot(x, np.sin(x), label='Sin x')
plt.plot(x, np.cos(x), label='Cos X')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Marker Data Point

# %%
plt.figure(figsize=(8,7))
x = np.random.RandomState(0)
list_marker = ['o', 'p', 'v', '+', 'x']
for marker in list_marker:
    plt.plot(x.rand(5
), x.rand(5), marker=marker, linestyle='None', label=marker)

plt.legend()
plt.show()
